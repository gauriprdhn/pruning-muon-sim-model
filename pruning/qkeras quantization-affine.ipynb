# %%
import pandas as pd
import numpy as np
import math
import h5py
from qkeras import *
from qkeras import utils
import tensorflow as tf
from sklearn.model_selection import train_test_split
print(tf.__version__)
from tensorflow.keras.models import Sequential, Model,model_from_json
from keras.layers import Input,Dense, BatchNormalization
from keras import initializers, regularizers, optimizers, losses
from nn_globals import *
from nn_encode_displ import nlayers, nvariables
from nn_models import (lr_decay, modelbestcheck, modelbestcheck_weights)
from nn_training import train_model
from nn_models import load_my_model, update_keras_custom_objects
from keras.models import Model
tf.compat.v1.logging.set_verbosity(tf.compat.v1.logging.ERROR)

# Setup matplotlib
plt.style.use('tdrstyle.mplstyle')

from nn_plotting import (gaus, fit_gaus, np_printoptions, \
                         find_efficiency_errors)

eps = 1e-7
my_cmap = plt.cm.viridis
my_cmap.set_under('w',1)
my_palette = ("#377eb8", "#e41a1c", "#984ea3", "#ff7f00", "#4daf4a")
# Out:
# [INFO    ] Using numpy 1.18.5
# [INFO    ] Using tensorflow 2.4.1
# [INFO    ] Using keras 2.4.3
# [INFO    ] Using scipy 1.7.0
# [INFO    ] Using sklearn 0.24.2
# 2.4.1
# <ipython-input-2-1d3da5d30478>:29: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("viridis"))
#   my_cmap.set_under('w',1)

# %%
class evaluate:
    def __init__(self,X_test,y_test):
        self.X = X_test
        self.y = y_test[0]
        self.dxy = y_test[1]
    
    def compute_data_statistics(self,ctype = "y",label="data"):
        if ctype == "y":
            x = self.recalibrate(self.y,reg_pt_scale)
            x = x**(-1)
        else:
            x = self.recalibrate(self.dxy,reg_dxy_scale)
        df_describe = pd.DataFrame(x, columns = [label])
        print(df_describe.describe())
    
    def rmse(self,y_true, y_predicted):
        assert(y_true.shape[0] == y_predicted.shape[0])
        n = y_true.shape[0]
        sum_square = np.sum((y_true - y_predicted)**2)
        return math.sqrt(sum_square/n)
    
    def adjusted_r_2(self,y_true, y_predicted):
        y_addC = sm.add_constant(y_true)
        result = sm.OLS(y_predicted, y_addC).fit()
        print(result.rsquared, result.rsquared_adj)

    def recalibrate(self,x,scale):
        return x/scale
    
    def inverse(self,arr):
        arr_inv = 1./arr
        arr_inv[arr_inv == np.inf] = 0.
        return arr_inv
    
    def predict(self,model,batch_size = 256):
        y_test_true = self.recalibrate(self.y,reg_pt_scale)
        dxy_test_true = self.recalibrate(self.dxy, reg_dxy_scale)
        
        y_test = model.predict(self.X,batch_size = 2000)
        y_test_meas = y_test[:,0]
        dxy_test_meas = y_test[:,1]
        y_test_meas = self.recalibrate(y_test_meas,reg_pt_scale)
        dxy_test_meas = self.recalibrate(dxy_test_meas,reg_dxy_scale)   
    
        y_test_meas = y_test_meas.reshape(-1)
        dxy_test_meas = dxy_test_meas.reshape(-1)

        return y_test_meas, dxy_test_meas
    
    def get_error(self,y_predicted,ctype = "y"):
        if ctype == "y":
            y_test_true = self.recalibrate(self.y,reg_pt_scale)
            return self.rmse(self.inverse(y_test_true),self.inverse(y_predicted))
        else:
            dxy_test_true = self.recalibrate(self.dxy, reg_dxy_scale)
            return self.rmse(dxy_test_true,y_predicted)

def k_fold_validation(model, x, y, dxy, folds =10):
    x_copy = np.copy(x)
    y_copy = np.copy(y)
    dxy_copy = np.copy(dxy)
    assert x_copy.shape[0] == y_copy.shape[0] == dxy_copy.shape[0]
    fold_size = int(x_copy.shape[0] / folds)
    x_splits, y_splits, dxy_splits = [], [], []
    for i in range(folds):
        indices = np.random.choice(x_copy.shape[0],fold_size, replace=False)  
        x_splits.append(x_copy[indices])
        y_splits.append(y_copy[indices])
        dxy_splits.append(dxy_copy[indices])
        x_copy = np.delete(x_copy,indices,axis = 0)
        y_copy = np.delete(y_copy,indices,axis = 0)
        dxy_copy = np.delete(dxy_copy,indices,axis = 0)
    rmse_y, rmse_dxy = [],[]
    for i in range(folds):
        evaluate_obj = evaluate(x_splits[i], tuple([y_splits[i],dxy_splits[i]]))
        y_predicted , dxy_predicted = evaluate_obj.predict(model = model)
        rmse_y.append(evaluate_obj.get_error(y_predicted,ctype="y"))
        rmse_dxy.append(evaluate_obj.get_error(dxy_predicted,ctype="dxy"))
    print('Average RMSE for '+ str(folds) + '-fold cv for y:', np.mean(rmse_y))
    print('Average RMSE for '+ str(folds) + '-fold cv for dxy:', np.mean(rmse_dxy))
    
def huber_loss(y_true, y_pred, delta=1.345):
    x = K.abs(y_true - y_pred)
    squared_loss = 0.5*K.square(x)
    absolute_loss = delta * (x - 0.5*delta)
    #xx = K.switch(x < delta, squared_loss, absolute_loss)
    xx = tf.where(x < delta, squared_loss, absolute_loss)  # needed for tensorflow
    return K.mean(xx, axis=-1)

def get_sparsity(weights):
    """
    Code borrowed from https://github.com/google/qkeras/blob/master/qkeras/utils.py#L937
    Returns the sparsity as the ratio of non-zero weights to the total weights within the weights matrix.
    """
    return 1.0 - np.count_nonzero(weights) / float(weights.size)

# %%
infile_muon_displ = "NN_input_params_FlatXYZ.npz"

nentries = 100000000

def _handle_nan_in_x(x):
    x[np.isnan(x)] = 0.0
    x[x==-999.0] = 0.0
    return x

def _zero_out_x(x):
    x = 0.0
    return x
    
def _fixME1Ring(x):
    for i in range(len(x)):
        if (x[i,0] != 0.0): x[i,18] = x[i,18] + 1
    return x   

def muon_data(filename, reg_pt_scale=1.0, reg_dxy_scale=1.0, correct_for_eta=False):
    try:
        logger.info('Loading muon data from {0} ...'.format(filename))
        loaded = np.load(filename)
        the_variables = loaded['variables']
        the_parameters = loaded['parameters']
        # print(the_variables.shape)
        the_variables = the_variables[:nentries]
        the_parameters = the_parameters[:nentries]
        logger.info('Loaded the variables with shape {0}'.format(the_variables.shape))
        logger.info('Loaded the parameters with shape {0}'.format(the_parameters.shape))
    except:
        logger.error('Failed to load data from file: {0}'.format(filename))

    assert(the_variables.shape[0] == the_parameters.shape[0])
    _handle_nan_in_x(the_variables)
      #_fixME1Ring(the_variables)
    _handle_nan_in_x(the_parameters)
    mask = np.logical_or(np.logical_or( np.logical_or((the_variables[:,23] == 11), (the_variables[:,23] == 13)), (the_variables[:,23] == 14)),(the_variables[:,23] == 15)) 

    the_variables = the_variables[mask]  
    the_parameters = the_parameters[mask]  
    assert(the_variables.shape[0] == the_parameters.shape[0])

    x = the_variables[:,0:23]
    y = reg_pt_scale*the_parameters[:,0]
#    print (x[0:30,:], the_variables[0:30,23])
#    print (y[0:30])
    phi = the_parameters[:,1] 
    eta = the_parameters[:,2] 
    vx = the_parameters[:,3] 
    vy = the_parameters[:,4] 
    vz = the_parameters[:,5]      
    dxy = vy * np.cos(phi) - vx * np.sin(phi) 
    dz = vz
    w = np.abs(y)/0.2 + 1.0
    x_mask = the_parameters[:,5]
    x_road = the_parameters[:,5] 
    _zero_out_x(x_mask)
    _zero_out_x(x_road)  
    logger.info('Loaded the encoded variables with shape {0}'.format(x.shape))
    logger.info('Loaded the encoded parameters with shape {0}'.format(y.shape))

    return x, y, dxy, dz, w, x_mask, x_road

def muon_data_split(filename, reg_pt_scale=1.0, reg_dxy_scale=1.0, test_size=0.5, correct_for_eta=False):
    x, y, dxy, dz, w, x_mask, x_road = muon_data(filename, reg_pt_scale=reg_pt_scale, reg_dxy_scale=reg_dxy_scale, correct_for_eta=correct_for_eta)

    # Split dataset in training and testing
    x_train, x_test, y_train, y_test, dxy_train, dxy_test, dz_train, dz_test, w_train, w_test, x_mask_train, x_mask_test, x_road_train, x_road_test = train_test_split(x, y, dxy, dz, w, x_mask, x_road, test_size=test_size)
    logger.info('Loaded # of training and testing events: {0}'.format((x_train.shape[0], x_test.shape[0])))

    # Check for cases where the number of events in the last batch could be too few
    validation_split = 0.1
    train_num_samples = int(x_train.shape[0] * (1.0-validation_split))
    val_num_samples = x_train.shape[0] - train_num_samples
    batch_size = 128
    if (train_num_samples%batch_size) < 100:
        logger.warning('The last batch for training could be too few! ({0}%{1})={2}. Please change test_size.'.format(train_num_samples, batch_size, train_num_samples%batch_size))
        logger.warning('Try this formula: int(int({0}*{1})*{2}) % 128'.format(x.shape[0], 1.0-test_size, 1.0-validation_split))
    train_num_samples = int(x_train.shape[0] * 2 * (1.0-validation_split))
    val_num_samples = x_train.shape[0] - train_num_samples
    batch_size = 128
    if (train_num_samples%batch_size) < 100:
        logger.warning('The last batch for training after mixing could be too few! ({0}%{1})={2}. Please change test_size.'.format(train_num_samples, batch_size, train_num_samples%batch_size))
        logger.warning('Try this formula: int(int({0}*{1})*2*{2}) % 128'.format(x.shape[0], 1.0-test_size, 1.0-validation_split))
    return x_train, x_test, y_train, y_test, dxy_train, dxy_test, dz_train, dz_test, w_train, w_test, x_mask_train, x_mask_test, x_road_train, x_road_test

# %%
# Import muon data
# 'x' is the array of input variables, 'y' is the q/pT
x_train_displ, x_test_displ, y_train_displ, y_test_displ, dxy_train_displ, dxy_test_displ, dz_train_displ, dz_test_displ, \
w_train_displ, w_test_displ, x_mask_train_displ, x_mask_test_displ, x_road_train_displ, x_road_test_displ = \
      muon_data_split(infile_muon_displ, reg_pt_scale=reg_pt_scale, reg_dxy_scale=reg_dxy_scale, test_size=0.315)

y_train_displ = np.abs(y_train_displ)
y_test_displ = np.abs(y_test_displ)
# Out:
# [INFO    ] Loading muon data from NN_input_params_FlatXYZ.npz ...
# [INFO    ] Loaded the variables with shape (19300000, 25)
# [INFO    ] Loaded the parameters with shape (19300000, 6)
# [INFO    ] Loaded the encoded variables with shape (3284620, 23)
# [INFO    ] Loaded the encoded parameters with shape (3284620,)
# [INFO    ] Loaded # of training and testing events: (2249964, 1034656)
# [WARNING ] The last batch for training could be too few! (2024967%128)=7. Please change test_size.
# [WARNING ] Try this formula: int(int(3284620*0.685)*0.9) % 128
# [WARNING ] The last batch for training after mixing could be too few! (4049935%128)=15. Please change test_size.
# [WARNING ] Try this formula: int(int(3284620*0.685)*2*0.9) % 128

# %% [markdown]
# ### Pre-Quantization Data Analysis:

# %%
# # Analysing dependencies in the data
# x = np.concatenate((x_train_displ,x_test_displ),axis=0)
# y = np.concatenate((y_train_displ,y_test_displ),axis=0)
# dxy = np.concatenate((dxy_train_displ,dxy_test_displ),axis=0)

# df = pd.DataFrame(x, columns = ["dphi_1","dphi_2","dphi_3","dphi_4","dphi_5","dphi_6",
#                                            "dtheta_1","dtheta_2","dtheta_3","dtheta_4","dtheta_5", "dtheta_6",
#                                            "bend_1","bend_2","bend_3","bend_4",
#                                            "FR","track theta","ME11",
#                                            "RPC_1","RPC_2","RPC_3","RPC_4"])
# df["Target momentum"] = y
# df["Target dxy"] = dxy
# # C_mat = df[["dphi_1","dphi_2","dphi_3","dphi_4","dphi_5","dphi_6",
# #             "dtheta_1","dtheta_2","dtheta_3","dtheta_4","dtheta_5", "dtheta_6",
# #            "track theta","Target momentum", "Target dxy"]].corr()
# C_mat = df.corr()
# fig = plt.figure(figsize = (7,7),dpi = 100)
# sns.heatmap(C_mat, vmax = .8, square = True,cmap = "YlGnBu")
# plt.show()

# %%
# y = np.concatenate((y_train_displ, y_test_displ))
# dxy = np.concatenate((dxy_train_displ, dxy_test_displ))
# assert(y.shape[0] == dxy.shape[0])
# stats = evaluate(x_train_displ,tuple([y,dxy]))
# stats.compute_data_statistics(ctype="y",label = "momentum")

# %%
# stats.compute_data_statistics(ctype="dxy",label="dxy")

# %% [markdown]
# ### Defining the Quantized Model:

# %%
def create_model_quantized(nvariables, lr=0.001, clipnorm=10., initializer = "he_uniform",
                           nodes1=64, nodes2=32, nodes3=16, outnodes=2,
                          l1_reg = 0.0, l2_reg = 0.0):
    regularizer = regularizers.L1L2(l1=l1_reg, l2=l2_reg)
    bn_momentum = 0.9
    eps = 1e-4
    x = x_in = Input((nvariables,))
    x = QBatchNormalization(epsilon=eps, momentum=bn_momentum,name="bn-input")(x)
    
    x = QDense(nodes1, 
               kernel_quantizer="quantized_bits(bits=10,integer=5,symmetric=False,use_stochastic_rounding=True)",
               kernel_initializer=initializer,
               use_bias = False,
               kernel_regularizer = regularizer,
               name="hidden-dense-1")(x)
    x = BatchNormalization(epsilon = eps, momentum  = bn_momentum, name = "bn-1")(x)
    x = QActivation(activation="quantized_relu(bits=10,integer=5,use_sigmoid=True,use_stochastic_rounding=True)",
                    name="act_1")(x)
    
    if nodes2:
    
        x = QDense(nodes2, 
                   kernel_quantizer="quantized_bits(bits=10,integer=5,symmetric=False,use_stochastic_rounding=True)", 
                   kernel_initializer=initializer,
                   use_bias = False,
                   kernel_regularizer = regularizer,
                   name="hidden-dense-2")(x)
        x = BatchNormalization(epsilon = eps, momentum  = bn_momentum, name = "bn-2")(x)
        x = QActivation(activation="quantized_relu(bits=10,integer=5, use_sigmoid=True,use_stochastic_rounding=True)", 
                        name="act_2")(x)
        
        if nodes3:

            x = QDense(nodes3, 
                       kernel_quantizer="quantized_bits(bits=10,integer=5,symmetric=False,use_stochastic_rounding=True)", 
                       kernel_initializer=initializer,
                       kernel_regularizer = regularizer,
                       use_bias = False,
                       name="hidden-dense-3")(x)
            x = BatchNormalization(epsilon = eps, momentum  = bn_momentum, name = "bn-3")(x)
            x = QActivation(activation="quantized_relu(bits=10,integer=5, use_sigmoid=True,use_stochastic_rounding=True)", 
                            name="act_3")(x)

    x = QDense(outnodes,
                kernel_quantizer="quantized_bits(bits=10,integer=5,symmetric=False,use_stochastic_rounding=True)",
                kernel_initializer = initializer,
                use_bias = True,
                name="dense-output")(x)
    x = Activation("linear")(x)
    
    model = Model(inputs=x_in, outputs=x,name="qmodel")
    
    adam = optimizers.Adam(lr=lr, clipnorm=clipnorm)
    model.compile(optimizer=adam, loss=huber_loss, metrics=['accuracy'])
    model.summary()
    
    return model

# %%
assert(keras.backend.backend() == 'tensorflow')

normal_epochs = 300
normal_batch_size = 500
l1_reg = 0.0
l2_reg = 1e-4
learning_rate = 1e-3

qmodel = create_model_quantized(nvariables=nvariables, lr=learning_rate, clipnorm=gradient_clip_norm, 
                              nodes1=20, nodes2=15, nodes3=10, outnodes=2,
                               l1_reg = l1_reg, l2_reg = l2_reg)

logger.info('Training model with l1_reg: {0} l2_reg: {1}'.format(l1_reg, l2_reg))

history = train_model(qmodel, x_train_displ, np.column_stack((y_train_displ, dxy_train_displ)),
#                     save_model=False, 
                      epochs=normal_epochs, 
                      batch_size=normal_batch_size,
                      callbacks=[lr_decay], 
                      validation_split=0.1, 
                      verbose=True)

metrics = [len(history.history['loss']), history.history['loss'][-1], history.history['val_loss'][-1]]
logger.info('Epoch {0}/{0} - loss: {1} - val_loss: {2}'.format(*metrics))
# Out:
# [INFO    ] Training model with l1_reg: 0.0 l2_reg: 0.0001
# [INFO    ] Begin training ...
# Model: "qmodel"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 23)]              0
# _________________________________________________________________
# bn-input (QBatchNormalizatio (None, 23)                92
# _________________________________________________________________
# hidden-dense-1 (QDense)      (None, 20)                460
# _________________________________________________________________
# bn-1 (BatchNormalization)    (None, 20)                80
# _________________________________________________________________
# act_1 (QActivation)          (None, 20)                0
# _________________________________________________________________
# hidden-dense-2 (QDense)      (None, 15)                300
# _________________________________________________________________
# bn-2 (BatchNormalization)    (None, 15)                60
# _________________________________________________________________
# act_2 (QActivation)          (None, 15)                0
# _________________________________________________________________
# hidden-dense-3 (QDense)      (None, 10)                150
# _________________________________________________________________
# bn-3 (BatchNormalization)    (None, 10)                40
# _________________________________________________________________
# act_3 (QActivation)          (None, 10)                0
# _________________________________________________________________
# dense-output (QDense)        (None, 2)                 22
# _________________________________________________________________
# activation (Activation)      (None, 2)                 0
# =================================================================
# Total params: 1,204
# Trainable params: 1,068
# Non-trainable params: 136
# _________________________________________________________________
# Epoch 1/300
#
# Epoch 00001: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 26s 6ms/step - loss: 30.8296 - accuracy: 0.8861 - val_loss: 11.6027 - val_accuracy: 0.9294
# Epoch 2/300
#
# Epoch 00002: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 23s 6ms/step - loss: 11.9259 - accuracy: 0.9298 - val_loss: 11.8427 - val_accuracy: 0.9335
# Epoch 3/300
#
# Epoch 00003: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 11.5591 - accuracy: 0.9322 - val_loss: 11.4151 - val_accuracy: 0.9355
# Epoch 4/300
#
# Epoch 00004: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 11.3006 - accuracy: 0.9332 - val_loss: 10.8967 - val_accuracy: 0.9355
# Epoch 5/300
#
# Epoch 00005: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 25s 6ms/step - loss: 11.1963 - accuracy: 0.9336 - val_loss: 12.3318 - val_accuracy: 0.9347
# Epoch 6/300
#
# Epoch 00006: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 11.0860 - accuracy: 0.9339 - val_loss: 12.0826 - val_accuracy: 0.9309
# Epoch 7/300
#
# Epoch 00007: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 27s 7ms/step - loss: 11.0289 - accuracy: 0.9338 - val_loss: 11.0988 - val_accuracy: 0.9347
# Epoch 8/300
#
# Epoch 00008: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.9701 - accuracy: 0.9343 - val_loss: 10.8099 - val_accuracy: 0.9349
# Epoch 9/300
#
# Epoch 00009: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.9314 - accuracy: 0.9342 - val_loss: 10.8523 - val_accuracy: 0.9351
# Epoch 10/300
#
# Epoch 00010: LearningRateScheduler reducing learning rate to 0.0010000000474974513.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.9783 - accuracy: 0.9343 - val_loss: 11.3201 - val_accuracy: 0.9323
# Epoch 11/300
#
# Epoch 00011: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 27s 7ms/step - loss: 10.8942 - accuracy: 0.9343 - val_loss: 11.4449 - val_accuracy: 0.9346
# Epoch 12/300
#
# Epoch 00012: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 25s 6ms/step - loss: 10.8942 - accuracy: 0.9345 - val_loss: 11.7592 - val_accuracy: 0.9345
# Epoch 13/300
#
# Epoch 00013: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.8672 - accuracy: 0.9344 - val_loss: 11.2126 - val_accuracy: 0.9313
# Epoch 14/300
#
# Epoch 00014: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.8330 - accuracy: 0.9352 - val_loss: 10.8307 - val_accuracy: 0.9364
# Epoch 15/300
#
# Epoch 00015: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.8558 - accuracy: 0.9346 - val_loss: 11.0596 - val_accuracy: 0.9371
# Epoch 16/300
#
# Epoch 00016: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.8199 - accuracy: 0.9348 - val_loss: 12.0318 - val_accuracy: 0.9353
# Epoch 17/300
#
# Epoch 00017: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 21s 5ms/step - loss: 10.8170 - accuracy: 0.9352 - val_loss: 11.4787 - val_accuracy: 0.9345
# Epoch 18/300
#
# Epoch 00018: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 21s 5ms/step - loss: 10.8301 - accuracy: 0.9350 - val_loss: 10.8541 - val_accuracy: 0.9359
# Epoch 19/300
#
# Epoch 00019: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 21s 5ms/step - loss: 10.8157 - accuracy: 0.9351 - val_loss: 12.2166 - val_accuracy: 0.9286
# Epoch 20/300
#
# Epoch 00020: LearningRateScheduler reducing learning rate to 0.0009000000427477062.
# 4050/4050 [==============================] - 21s 5ms/step - loss: 10.7823 - accuracy: 0.9353 - val_loss: 10.7918 - val_accuracy: 0.9354
# Epoch 21/300
#
# Epoch 00021: LearningRateScheduler reducing learning rate to 0.0008100000384729356.
# 4050/4050 [==============================] - 21s 5ms/step - loss: 10.7774 - accuracy: 0.9355 - val_loss: 11.3944 - val_accuracy: 0.9357
# Epoch 22/300
#
# Epoch 00022: LearningRateScheduler reducing learning rate to 0.0008100000559352338.
# 4050/4050 [==============================] - 23s 6ms/step - loss: 10.7832 - accuracy: 0.9351 - val_loss: 11.0108 - val_accuracy: 0.9371
# Epoch 23/300
#
# Epoch 00023: LearningRateScheduler reducing learning rate to 0.0008100000559352338.
# 4050/4050 [==============================] - 26s 6ms/step - loss: 10.7839 - accuracy: 0.9349 - val_loss: 11.6222 - val_accuracy: 0.9355
# Epoch 24/300
#
# Epoch 00024: LearningRateScheduler reducing learning rate to 0.0008100000559352338.
# 4050/4050 [==============================] - 26s 6ms/step - loss: 10.7862 - accuracy: 0.9351 - val_loss: 12.0352 - val_accuracy: 0.9343
# Epoch 25/300
#
# Epoch 00025: LearningRateScheduler reducing learning rate to 0.0008100000559352338.
# 4050/4050 [==============================] - 28s 7ms/step - loss: 10.7858 - accuracy: 0.9354 - val_loss: 11.5297 - val_accuracy: 0.9345
# Epoch 26/300
#
# Epoch 00026: LearningRateScheduler reducing learning rate to 0.0008100000559352338.
# 4050/4050 [==============================] - 23s 6ms/step - loss: 10.7686 - accuracy: 0.9349 - val_loss: 12.2932 - val_accuracy: 0.9359
# Epoch 27/300
#
# Epoch 00027: LearningRateScheduler reducing learning rate to 0.0008100000559352338.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.7699 - accuracy: 0.9353 - val_loss: 11.5745 - val_accuracy: 0.9356
# Epoch 28/300
#
# Epoch 00028: LearningRateScheduler reducing learning rate to 0.0008100000559352338.
# 4050/4050 [==============================] - 25s 6ms/step - loss: 10.7297 - accuracy: 0.9355 - val_loss: 11.6854 - val_accuracy: 0.9347
# Epoch 29/300
#
# Epoch 00029: LearningRateScheduler reducing learning rate to 0.0008100000559352338.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.7491 - accuracy: 0.9357 - val_loss: 12.1585 - val_accuracy: 0.9354
# Epoch 30/300
#
# Epoch 00030: LearningRateScheduler reducing learning rate to 0.0008100000559352338.
# 4050/4050 [==============================] - 29s 7ms/step - loss: 10.7939 - accuracy: 0.9351 - val_loss: 11.1742 - val_accuracy: 0.9335
# Epoch 31/300
#
# Epoch 00031: LearningRateScheduler reducing learning rate to 0.0007290000503417104.
# 4050/4050 [==============================] - 26s 6ms/step - loss: 10.7234 - accuracy: 0.9354 - val_loss: 11.9649 - val_accuracy: 0.9366
# Epoch 32/300
#
# Epoch 00032: LearningRateScheduler reducing learning rate to 0.0007290000794455409.
# 4050/4050 [==============================] - 27s 7ms/step - loss: 10.7177 - accuracy: 0.9354 - val_loss: 11.0245 - val_accuracy: 0.9350
# Epoch 33/300
#
# Epoch 00033: LearningRateScheduler reducing learning rate to 0.0007290000794455409.
# 4050/4050 [==============================] - 25s 6ms/step - loss: 10.7230 - accuracy: 0.9349 - val_loss: 11.8795 - val_accuracy: 0.9329
# Epoch 34/300
#
# Epoch 00034: LearningRateScheduler reducing learning rate to 0.0007290000794455409.
# 4050/4050 [==============================] - 23s 6ms/step - loss: 10.7130 - accuracy: 0.9354 - val_loss: 10.7019 - val_accuracy: 0.9367
# Epoch 35/300
#
# Epoch 00035: LearningRateScheduler reducing learning rate to 0.0007290000794455409.
# 4050/4050 [==============================] - 23s 6ms/step - loss: 10.6883 - accuracy: 0.9352 - val_loss: 11.3853 - val_accuracy: 0.9368
# Epoch 36/300
#
# Epoch 00036: LearningRateScheduler reducing learning rate to 0.0007290000794455409.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.6943 - accuracy: 0.9353 - val_loss: 11.2028 - val_accuracy: 0.9349
# Epoch 37/300
#
# Epoch 00037: LearningRateScheduler reducing learning rate to 0.0007290000794455409.
# 4050/4050 [==============================] - 23s 6ms/step - loss: 10.7109 - accuracy: 0.9354 - val_loss: 10.5723 - val_accuracy: 0.9360
# Epoch 38/300
#
# Epoch 00038: LearningRateScheduler reducing learning rate to 0.0007290000794455409.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.6999 - accuracy: 0.9354 - val_loss: 12.6889 - val_accuracy: 0.9352
# Epoch 39/300
#
# Epoch 00039: LearningRateScheduler reducing learning rate to 0.0007290000794455409.
# 4050/4050 [==============================] - 22s 6ms/step - loss: 10.6961 - accuracy: 0.9354 - val_loss: 11.1598 - val_accuracy: 0.9363
# Epoch 40/300
#
# Epoch 00040: LearningRateScheduler reducing learning rate to 0.0007290000794455409.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.6490 - accuracy: 0.9355 - val_loss: 10.6112 - val_accuracy: 0.9374
# Epoch 41/300
#
# Epoch 00041: LearningRateScheduler reducing learning rate to 0.0006561000715009868.
# 4050/4050 [==============================] - 31s 8ms/step - loss: 10.6705 - accuracy: 0.9354 - val_loss: 10.4991 - val_accuracy: 0.9364
# Epoch 42/300
#
# Epoch 00042: LearningRateScheduler reducing learning rate to 0.0006561000482179224.
# 4050/4050 [==============================] - 26s 6ms/step - loss: 10.6694 - accuracy: 0.9355 - val_loss: 10.7104 - val_accuracy: 0.9370
# Epoch 43/300
#
# Epoch 00043: LearningRateScheduler reducing learning rate to 0.0006561000482179224.
# 4050/4050 [==============================] - 25s 6ms/step - loss: 10.6592 - accuracy: 0.9354 - val_loss: 10.7613 - val_accuracy: 0.9366
# Epoch 44/300
#
# Epoch 00044: LearningRateScheduler reducing learning rate to 0.0006561000482179224.
# 4050/4050 [==============================] - 25s 6ms/step - loss: 10.6700 - accuracy: 0.9355 - val_loss: 12.3118 - val_accuracy: 0.9346
# Epoch 45/300
#
# Epoch 00045: LearningRateScheduler reducing learning rate to 0.0006561000482179224.
# 4050/4050 [==============================] - 25s 6ms/step - loss: 10.6640 - accuracy: 0.9357 - val_loss: 11.8704 - val_accuracy: 0.9368
# Epoch 46/300
#
# Epoch 00046: LearningRateScheduler reducing learning rate to 0.0006561000482179224.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.6505 - accuracy: 0.9355 - val_loss: 11.6714 - val_accuracy: 0.9356
# Epoch 47/300
#
# Epoch 00047: LearningRateScheduler reducing learning rate to 0.0006561000482179224.
# 4050/4050 [==============================] - 25s 6ms/step - loss: 10.6564 - accuracy: 0.9355 - val_loss: 10.3242 - val_accuracy: 0.9373
# Epoch 48/300
#
# Epoch 00048: LearningRateScheduler reducing learning rate to 0.0006561000482179224.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.6432 - accuracy: 0.9357 - val_loss: 11.2333 - val_accuracy: 0.9371
# Epoch 49/300
#
# Epoch 00049: LearningRateScheduler reducing learning rate to 0.0006561000482179224.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.6434 - accuracy: 0.9357 - val_loss: 11.0636 - val_accuracy: 0.9359
# Epoch 50/300
#
# Epoch 00050: LearningRateScheduler reducing learning rate to 0.0006561000482179224.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.6687 - accuracy: 0.9357 - val_loss: 12.0541 - val_accuracy: 0.9353
# Epoch 51/300
#
# Epoch 00051: LearningRateScheduler reducing learning rate to 0.0005904900433961303.
# 4050/4050 [==============================] - 26s 6ms/step - loss: 10.6571 - accuracy: 0.9356 - val_loss: 11.9287 - val_accuracy: 0.9342
# Epoch 52/300
#
# Epoch 00052: LearningRateScheduler reducing learning rate to 0.0005904900608584285.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.6551 - accuracy: 0.9356 - val_loss: 10.4700 - val_accuracy: 0.9375
# Epoch 53/300
#
# Epoch 00053: LearningRateScheduler reducing learning rate to 0.0005904900608584285.
# 4050/4050 [==============================] - 23s 6ms/step - loss: 10.6248 - accuracy: 0.9355 - val_loss: 11.0213 - val_accuracy: 0.9342
# Epoch 54/300
#
# Epoch 00054: LearningRateScheduler reducing learning rate to 0.0005904900608584285.
# 4050/4050 [==============================] - 23s 6ms/step - loss: 10.6163 - accuracy: 0.9359 - val_loss: 12.4127 - val_accuracy: 0.9352
# Epoch 55/300
#
# Epoch 00055: LearningRateScheduler reducing learning rate to 0.0005904900608584285.
# 4050/4050 [==============================] - 23s 6ms/step - loss: 10.6164 - accuracy: 0.9357 - val_loss: 10.5034 - val_accuracy: 0.9367
# Epoch 56/300
#
# Epoch 00056: LearningRateScheduler reducing learning rate to 0.0005904900608584285.
# 4050/4050 [==============================] - 24s 6ms/step - loss: 10.6475 - accuracy: 0.9356 - val_loss: 12.9466 - val_accuracy: 0.9293
# Epoch 57/300
#
# Epoch 00057: LearningRateScheduler reducing learning rate to 0.0005904900608584285.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.6184 - accuracy: 0.9358 - val_loss: 10.5333 - val_accuracy: 0.9366
# Epoch 58/300
#
# Epoch 00058: LearningRateScheduler reducing learning rate to 0.0005904900608584285.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.6245 - accuracy: 0.9358 - val_loss: 11.7978 - val_accuracy: 0.9329
# Epoch 59/300
#
# Epoch 00059: LearningRateScheduler reducing learning rate to 0.0005904900608584285.
# 4050/4050 [==============================] - 21s 5ms/step - loss: 10.6204 - accuracy: 0.9356 - val_loss: 11.8061 - val_accuracy: 0.9316
# Epoch 60/300
#
# Epoch 00060: LearningRateScheduler reducing learning rate to 0.0005904900608584285.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.6215 - accuracy: 0.9351 - val_loss: 12.1894 - val_accuracy: 0.9324
# Epoch 61/300
#
# Epoch 00061: LearningRateScheduler reducing learning rate to 0.0005314410547725857.
# 4050/4050 [==============================] - 22s 5ms/step - loss: 10.6204 - accuracy: 0.9357 - val_loss: 11.0307 - val_accuracy: 0.9348
# Epoch 62/300
#
# Epoch 00062: LearningRateScheduler reducing learning rate to 0.0005314410664141178.
# 4050/4050 [==============================] - 21s 5ms/step - loss: 10.6120 - accuracy: 0.9358 - val_loss: 10.3497 - val_accuracy: 0.9367
# Epoch 63/300
#
# Epoch 00063: LearningRateScheduler reducing learning rate to 0.0005314410664141178.
# 4050/4050 [==============================] - 8s 2ms/step - loss: 10.5965 - accuracy: 0.9360 - val_loss: 10.6332 - val_accuracy: 0.9351
# Epoch 64/300
#
# Epoch 00064: LearningRateScheduler reducing learning rate to 0.0005314410664141178.
# 4050/4050 [==============================] - 8s 2ms/step - loss: 10.5917 - accuracy: 0.9358 - val_loss: 10.2807 - val_accuracy: 0.9380
# Epoch 65/300
#
# Epoch 00065: LearningRateScheduler reducing learning rate to 0.0005314410664141178.
# 4050/4050 [==============================] - 8s 2ms/step - loss: 10.6401 - accuracy: 0.9357 - val_loss: 11.5067 - val_accuracy: 0.9341
# Epoch 66/300
#
# Epoch 00066: LearningRateScheduler reducing learning rate to 0.0005314410664141178.
# 4050/4050 [==============================] - 8s 2ms/step - loss: 10.6153 - accuracy: 0.9359 - val_loss: 11.7330 - val_accuracy: 0.9338
# Epoch 67/300
#
# Epoch 00067: LearningRateScheduler reducing learning rate to 0.0005314410664141178.
# 4050/4050 [==============================] - 8s 2ms/step - loss: 10.6216 - accuracy: 0.9355 - val_loss: 11.3371 - val_accuracy: 0.9328
# Epoch 68/300
#
# Epoch 00068: LearningRateScheduler reducing learning rate to 0.0005314410664141178.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.5846 - accuracy: 0.9356 - val_loss: 11.2845 - val_accuracy: 0.9361
# Epoch 69/300
#
# Epoch 00069: LearningRateScheduler reducing learning rate to 0.0005314410664141178.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.5861 - accuracy: 0.9357 - val_loss: 11.6220 - val_accuracy: 0.9362
# Epoch 70/300
#
# Epoch 00070: LearningRateScheduler reducing learning rate to 0.0005314410664141178.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.6097 - accuracy: 0.9356 - val_loss: 11.2535 - val_accuracy: 0.9340
# Epoch 71/300
#
# Epoch 00071: LearningRateScheduler reducing learning rate to 0.00047829695977270604.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.6064 - accuracy: 0.9356 - val_loss: 10.8755 - val_accuracy: 0.9354
# Epoch 72/300
#
# Epoch 00072: LearningRateScheduler reducing learning rate to 0.00047829694813117385.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.6229 - accuracy: 0.9357 - val_loss: 11.3102 - val_accuracy: 0.9382
# Epoch 73/300
#
# Epoch 00073: LearningRateScheduler reducing learning rate to 0.00047829694813117385.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.5903 - accuracy: 0.9357 - val_loss: 11.4033 - val_accuracy: 0.9335
# Epoch 74/300
#
# Epoch 00074: LearningRateScheduler reducing learning rate to 0.00047829694813117385.
# 4050/4050 [==============================] - 8s 2ms/step - loss: 10.5854 - accuracy: 0.9354 - val_loss: 10.2512 - val_accuracy: 0.9368
# Epoch 75/300
#
# Epoch 00075: LearningRateScheduler reducing learning rate to 0.00047829694813117385.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.5696 - accuracy: 0.9357 - val_loss: 10.8645 - val_accuracy: 0.9371
# Epoch 76/300
#
# Epoch 00076: LearningRateScheduler reducing learning rate to 0.00047829694813117385.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.5686 - accuracy: 0.9356 - val_loss: 10.4321 - val_accuracy: 0.9373
# Epoch 77/300
#
# Epoch 00077: LearningRateScheduler reducing learning rate to 0.00047829694813117385.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.5803 - accuracy: 0.9356 - val_loss: 10.6852 - val_accuracy: 0.9368
# Epoch 78/300
#
# Epoch 00078: LearningRateScheduler reducing learning rate to 0.00047829694813117385.
# 4050/4050 [==============================] - 9s 2ms/step - loss: 10.5628 - accuracy: 0.9358 - val_loss: 10.4930 - val_accuracy: 0.9385
# Epoch 79/300
#
# Epoch 00079: LearningRateScheduler reducing learning rate to 0.00047829694813117385.
# 4050/4050 [==============================] - 9s 2ms/step - loss: 10.5485 - accuracy: 0.9358 - val_loss: 11.4220 - val_accuracy: 0.9356
# Epoch 80/300
#
# Epoch 00080: LearningRateScheduler reducing learning rate to 0.00047829694813117385.
# 4050/4050 [==============================] - 10s 2ms/step - loss: 10.5662 - accuracy: 0.9357 - val_loss: 11.6166 - val_accuracy: 0.9302
# Epoch 81/300
#
# Epoch 00081: LearningRateScheduler reducing learning rate to 0.0004304672533180565.
# 4050/4050 [==============================] - 9s 2ms/step - loss: 10.5515 - accuracy: 0.9358 - val_loss: 11.5689 - val_accuracy: 0.9347
# Epoch 82/300
#
# Epoch 00082: LearningRateScheduler reducing learning rate to 0.00043046724749729037.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5452 - accuracy: 0.9359 - val_loss: 11.7726 - val_accuracy: 0.9331
# Epoch 83/300
#
# Epoch 00083: LearningRateScheduler reducing learning rate to 0.00043046724749729037.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.5634 - accuracy: 0.9357 - val_loss: 11.5376 - val_accuracy: 0.9335
# Epoch 84/300
#
# Epoch 00084: LearningRateScheduler reducing learning rate to 0.00043046724749729037.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5617 - accuracy: 0.9360 - val_loss: 11.7063 - val_accuracy: 0.9340
# Epoch 85/300
#
# Epoch 00085: LearningRateScheduler reducing learning rate to 0.00043046724749729037.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5522 - accuracy: 0.9359 - val_loss: 10.7328 - val_accuracy: 0.9370
# Epoch 86/300
#
# Epoch 00086: LearningRateScheduler reducing learning rate to 0.00043046724749729037.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5339 - accuracy: 0.9359 - val_loss: 10.7246 - val_accuracy: 0.9370
# Epoch 87/300
#
# Epoch 00087: LearningRateScheduler reducing learning rate to 0.00043046724749729037.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5302 - accuracy: 0.9360 - val_loss: 11.4620 - val_accuracy: 0.9257
# Epoch 88/300
#
# Epoch 00088: LearningRateScheduler reducing learning rate to 0.00043046724749729037.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5317 - accuracy: 0.9360 - val_loss: 11.6319 - val_accuracy: 0.9353
# Epoch 89/300
#
# Epoch 00089: LearningRateScheduler reducing learning rate to 0.00043046724749729037.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5489 - accuracy: 0.9360 - val_loss: 11.5038 - val_accuracy: 0.9329
# Epoch 90/300
#
# Epoch 00090: LearningRateScheduler reducing learning rate to 0.00043046724749729037.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5613 - accuracy: 0.9361 - val_loss: 10.6378 - val_accuracy: 0.9363
# Epoch 91/300
#
# Epoch 00091: LearningRateScheduler reducing learning rate to 0.00038742052274756136.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5281 - accuracy: 0.9358 - val_loss: 12.2143 - val_accuracy: 0.9333
# Epoch 92/300
#
# Epoch 00092: LearningRateScheduler reducing learning rate to 0.0003874205285683274.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5380 - accuracy: 0.9360 - val_loss: 12.1882 - val_accuracy: 0.9352
# Epoch 93/300
#
# Epoch 00093: LearningRateScheduler reducing learning rate to 0.0003874205285683274.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5335 - accuracy: 0.9359 - val_loss: 11.1899 - val_accuracy: 0.9350
# Epoch 94/300
#
# Epoch 00094: LearningRateScheduler reducing learning rate to 0.0003874205285683274.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5225 - accuracy: 0.9360 - val_loss: 10.7909 - val_accuracy: 0.9342
# Epoch 95/300
#
# Epoch 00095: LearningRateScheduler reducing learning rate to 0.0003874205285683274.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5352 - accuracy: 0.9360 - val_loss: 10.4147 - val_accuracy: 0.9373
# Epoch 96/300
#
# Epoch 00096: LearningRateScheduler reducing learning rate to 0.0003874205285683274.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5555 - accuracy: 0.9357 - val_loss: 11.2369 - val_accuracy: 0.9344
# Epoch 97/300
#
# Epoch 00097: LearningRateScheduler reducing learning rate to 0.0003874205285683274.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5247 - accuracy: 0.9361 - val_loss: 11.2648 - val_accuracy: 0.9348
# Epoch 98/300
#
# Epoch 00098: LearningRateScheduler reducing learning rate to 0.0003874205285683274.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.6000 - accuracy: 0.9359 - val_loss: 11.2652 - val_accuracy: 0.9364
# Epoch 99/300
#
# Epoch 00099: LearningRateScheduler reducing learning rate to 0.0003874205285683274.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.6378 - accuracy: 0.9357 - val_loss: 11.5384 - val_accuracy: 0.9353
# Epoch 100/300
#
# Epoch 00100: LearningRateScheduler reducing learning rate to 0.0003874205285683274.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5536 - accuracy: 0.9358 - val_loss: 11.1672 - val_accuracy: 0.9342
# Epoch 101/300
#
# Epoch 00101: LearningRateScheduler reducing learning rate to 0.0003486784757114947.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5247 - accuracy: 0.9362 - val_loss: 10.9291 - val_accuracy: 0.9371
# Epoch 102/300
#
# Epoch 00102: LearningRateScheduler reducing learning rate to 0.0003486784698907286.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5279 - accuracy: 0.9357 - val_loss: 11.3694 - val_accuracy: 0.9336
# Epoch 103/300
#
# Epoch 00103: LearningRateScheduler reducing learning rate to 0.0003486784698907286.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5489 - accuracy: 0.9357 - val_loss: 12.0874 - val_accuracy: 0.9307
# Epoch 104/300
#
# Epoch 00104: LearningRateScheduler reducing learning rate to 0.0003486784698907286.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.6929 - accuracy: 0.9347 - val_loss: 12.1553 - val_accuracy: 0.9262
# Epoch 105/300
#
# Epoch 00105: LearningRateScheduler reducing learning rate to 0.0003486784698907286.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5839 - accuracy: 0.9354 - val_loss: 13.8825 - val_accuracy: 0.9302
# Epoch 106/300
#
# Epoch 00106: LearningRateScheduler reducing learning rate to 0.0003486784698907286.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.6655 - accuracy: 0.9348 - val_loss: 10.9201 - val_accuracy: 0.9351
# Epoch 107/300
#
# Epoch 00107: LearningRateScheduler reducing learning rate to 0.0003486784698907286.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5740 - accuracy: 0.9353 - val_loss: 10.0966 - val_accuracy: 0.9379
# Epoch 108/300
#
# Epoch 00108: LearningRateScheduler reducing learning rate to 0.0003486784698907286.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5628 - accuracy: 0.9356 - val_loss: 10.7815 - val_accuracy: 0.9363
# Epoch 109/300
#
# Epoch 00109: LearningRateScheduler reducing learning rate to 0.0003486784698907286.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5636 - accuracy: 0.9358 - val_loss: 10.6871 - val_accuracy: 0.9335
# Epoch 110/300
#
# Epoch 00110: LearningRateScheduler reducing learning rate to 0.0003486784698907286.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5508 - accuracy: 0.9358 - val_loss: 11.0306 - val_accuracy: 0.9354
# Epoch 111/300
#
# Epoch 00111: LearningRateScheduler reducing learning rate to 0.00031381062290165574.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5332 - accuracy: 0.9358 - val_loss: 10.8024 - val_accuracy: 0.9351
# Epoch 112/300
#
# Epoch 00112: LearningRateScheduler reducing learning rate to 0.0003138106258120388.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5159 - accuracy: 0.9358 - val_loss: 10.8251 - val_accuracy: 0.9362
# Epoch 113/300
#
# Epoch 00113: LearningRateScheduler reducing learning rate to 0.0003138106258120388.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5128 - accuracy: 0.9358 - val_loss: 11.4778 - val_accuracy: 0.9362
# Epoch 114/300
#
# Epoch 00114: LearningRateScheduler reducing learning rate to 0.0003138106258120388.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5280 - accuracy: 0.9357 - val_loss: 10.3711 - val_accuracy: 0.9357
# Epoch 115/300
#
# Epoch 00115: LearningRateScheduler reducing learning rate to 0.0003138106258120388.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5298 - accuracy: 0.9355 - val_loss: 10.1261 - val_accuracy: 0.9377
# Epoch 116/300
#
# Epoch 00116: LearningRateScheduler reducing learning rate to 0.0003138106258120388.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4970 - accuracy: 0.9359 - val_loss: 10.4322 - val_accuracy: 0.9363
# Epoch 117/300
#
# Epoch 00117: LearningRateScheduler reducing learning rate to 0.0003138106258120388.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5119 - accuracy: 0.9362 - val_loss: 10.9033 - val_accuracy: 0.9350
# Epoch 118/300
#
# Epoch 00118: LearningRateScheduler reducing learning rate to 0.0003138106258120388.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5153 - accuracy: 0.9362 - val_loss: 10.5735 - val_accuracy: 0.9373
# Epoch 119/300
#
# Epoch 00119: LearningRateScheduler reducing learning rate to 0.0003138106258120388.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5210 - accuracy: 0.9361 - val_loss: 10.6919 - val_accuracy: 0.9354
# Epoch 120/300
#
# Epoch 00120: LearningRateScheduler reducing learning rate to 0.0003138106258120388.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5202 - accuracy: 0.9360 - val_loss: 10.3560 - val_accuracy: 0.9365
# Epoch 121/300
#
# Epoch 00121: LearningRateScheduler reducing learning rate to 0.0002824295632308349.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4968 - accuracy: 0.9358 - val_loss: 10.9144 - val_accuracy: 0.9368
# Epoch 122/300
#
# Epoch 00122: LearningRateScheduler reducing learning rate to 0.00028242956614121795.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5115 - accuracy: 0.9364 - val_loss: 10.1035 - val_accuracy: 0.9390
# Epoch 123/300
#
# Epoch 00123: LearningRateScheduler reducing learning rate to 0.00028242956614121795.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5095 - accuracy: 0.9360 - val_loss: 10.7754 - val_accuracy: 0.9359
# Epoch 124/300
#
# Epoch 00124: LearningRateScheduler reducing learning rate to 0.00028242956614121795.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5082 - accuracy: 0.9361 - val_loss: 10.5360 - val_accuracy: 0.9384
# Epoch 125/300
#
# Epoch 00125: LearningRateScheduler reducing learning rate to 0.00028242956614121795.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5508 - accuracy: 0.9360 - val_loss: 11.1711 - val_accuracy: 0.9334
# Epoch 126/300
#
# Epoch 00126: LearningRateScheduler reducing learning rate to 0.00028242956614121795.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5572 - accuracy: 0.9356 - val_loss: 10.9991 - val_accuracy: 0.9366
# Epoch 127/300
#
# Epoch 00127: LearningRateScheduler reducing learning rate to 0.00028242956614121795.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5353 - accuracy: 0.9359 - val_loss: 11.1879 - val_accuracy: 0.9351
# Epoch 128/300
#
# Epoch 00128: LearningRateScheduler reducing learning rate to 0.00028242956614121795.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5257 - accuracy: 0.9360 - val_loss: 11.2545 - val_accuracy: 0.9355
# Epoch 129/300
#
# Epoch 00129: LearningRateScheduler reducing learning rate to 0.00028242956614121795.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4863 - accuracy: 0.9362 - val_loss: 11.2490 - val_accuracy: 0.9371
# Epoch 130/300
#
# Epoch 00130: LearningRateScheduler reducing learning rate to 0.00028242956614121795.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4899 - accuracy: 0.9363 - val_loss: 11.2288 - val_accuracy: 0.9340
# Epoch 131/300
#
# Epoch 00131: LearningRateScheduler reducing learning rate to 0.00025418660952709616.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4862 - accuracy: 0.9360 - val_loss: 11.9876 - val_accuracy: 0.9343
# Epoch 132/300
#
# Epoch 00132: LearningRateScheduler reducing learning rate to 0.00025418659788556397.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5086 - accuracy: 0.9361 - val_loss: 10.5971 - val_accuracy: 0.9362
# Epoch 133/300
#
# Epoch 00133: LearningRateScheduler reducing learning rate to 0.00025418659788556397.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4815 - accuracy: 0.9360 - val_loss: 10.9107 - val_accuracy: 0.9355
# Epoch 134/300
#
# Epoch 00134: LearningRateScheduler reducing learning rate to 0.00025418659788556397.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5115 - accuracy: 0.9359 - val_loss: 10.6313 - val_accuracy: 0.9372
# Epoch 135/300
#
# Epoch 00135: LearningRateScheduler reducing learning rate to 0.00025418659788556397.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4888 - accuracy: 0.9362 - val_loss: 11.1910 - val_accuracy: 0.9337
# Epoch 136/300
#
# Epoch 00136: LearningRateScheduler reducing learning rate to 0.00025418659788556397.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5074 - accuracy: 0.9359 - val_loss: 11.6223 - val_accuracy: 0.9350
# Epoch 137/300
#
# Epoch 00137: LearningRateScheduler reducing learning rate to 0.00025418659788556397.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5123 - accuracy: 0.9357 - val_loss: 11.1341 - val_accuracy: 0.9346
# Epoch 138/300
#
# Epoch 00138: LearningRateScheduler reducing learning rate to 0.00025418659788556397.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5130 - accuracy: 0.9358 - val_loss: 10.4061 - val_accuracy: 0.9360
# Epoch 139/300
#
# Epoch 00139: LearningRateScheduler reducing learning rate to 0.00025418659788556397.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5117 - accuracy: 0.9362 - val_loss: 10.6998 - val_accuracy: 0.9374
# Epoch 140/300
#
# Epoch 00140: LearningRateScheduler reducing learning rate to 0.00025418659788556397.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5009 - accuracy: 0.9361 - val_loss: 10.4215 - val_accuracy: 0.9379
# Epoch 141/300
#
# Epoch 00141: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4946 - accuracy: 0.9362 - val_loss: 10.7502 - val_accuracy: 0.9370
# Epoch 142/300
#
# Epoch 00142: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4873 - accuracy: 0.9361 - val_loss: 10.2194 - val_accuracy: 0.9380
# Epoch 143/300
#
# Epoch 00143: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4912 - accuracy: 0.9361 - val_loss: 11.1301 - val_accuracy: 0.9366
# Epoch 144/300
#
# Epoch 00144: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5059 - accuracy: 0.9362 - val_loss: 10.2068 - val_accuracy: 0.9380
# Epoch 145/300
#
# Epoch 00145: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4912 - accuracy: 0.9363 - val_loss: 10.7226 - val_accuracy: 0.9370
# Epoch 146/300
#
# Epoch 00146: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4785 - accuracy: 0.9365 - val_loss: 10.3741 - val_accuracy: 0.9360
# Epoch 147/300
#
# Epoch 00147: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5385 - accuracy: 0.9363 - val_loss: 10.3351 - val_accuracy: 0.9382
# Epoch 148/300
#
# Epoch 00148: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.6914 - accuracy: 0.9355 - val_loss: 10.4940 - val_accuracy: 0.9372
# Epoch 149/300
#
# Epoch 00149: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.6496 - accuracy: 0.9355 - val_loss: 10.6898 - val_accuracy: 0.9375
# Epoch 150/300
#
# Epoch 00150: LearningRateScheduler reducing learning rate to 0.00022876793809700757.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.6059 - accuracy: 0.9354 - val_loss: 10.8383 - val_accuracy: 0.9361
# Epoch 151/300
#
# Epoch 00151: LearningRateScheduler reducing learning rate to 0.00020589114428730683.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5605 - accuracy: 0.9363 - val_loss: 10.8352 - val_accuracy: 0.9360
# Epoch 152/300
#
# Epoch 00152: LearningRateScheduler reducing learning rate to 0.00020589114865288138.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5630 - accuracy: 0.9362 - val_loss: 11.5601 - val_accuracy: 0.9327
# Epoch 153/300
#
# Epoch 00153: LearningRateScheduler reducing learning rate to 0.00020589114865288138.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5644 - accuracy: 0.9359 - val_loss: 11.9075 - val_accuracy: 0.9354
# Epoch 154/300
#
# Epoch 00154: LearningRateScheduler reducing learning rate to 0.00020589114865288138.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5619 - accuracy: 0.9359 - val_loss: 10.9598 - val_accuracy: 0.9330
# Epoch 155/300
#
# Epoch 00155: LearningRateScheduler reducing learning rate to 0.00020589114865288138.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5445 - accuracy: 0.9361 - val_loss: 11.2112 - val_accuracy: 0.9340
# Epoch 156/300
#
# Epoch 00156: LearningRateScheduler reducing learning rate to 0.00020589114865288138.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5090 - accuracy: 0.9363 - val_loss: 11.4431 - val_accuracy: 0.9368
# Epoch 157/300
#
# Epoch 00157: LearningRateScheduler reducing learning rate to 0.00020589114865288138.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5588 - accuracy: 0.9361 - val_loss: 11.1915 - val_accuracy: 0.9337
# Epoch 158/300
#
# Epoch 00158: LearningRateScheduler reducing learning rate to 0.00020589114865288138.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5516 - accuracy: 0.9362 - val_loss: 11.0682 - val_accuracy: 0.9372
# Epoch 159/300
#
# Epoch 00159: LearningRateScheduler reducing learning rate to 0.00020589114865288138.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5318 - accuracy: 0.9363 - val_loss: 10.4680 - val_accuracy: 0.9371
# Epoch 160/300
#
# Epoch 00160: LearningRateScheduler reducing learning rate to 0.00020589114865288138.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5438 - accuracy: 0.9359 - val_loss: 11.0078 - val_accuracy: 0.9372
# Epoch 161/300
#
# Epoch 00161: LearningRateScheduler reducing learning rate to 0.00018530203378759326.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5064 - accuracy: 0.9362 - val_loss: 11.3188 - val_accuracy: 0.9345
# Epoch 162/300
#
# Epoch 00162: LearningRateScheduler reducing learning rate to 0.0001853020366979763.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5151 - accuracy: 0.9366 - val_loss: 10.5354 - val_accuracy: 0.9368
# Epoch 163/300
#
# Epoch 00163: LearningRateScheduler reducing learning rate to 0.0001853020366979763.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5018 - accuracy: 0.9361 - val_loss: 12.3446 - val_accuracy: 0.9347
# Epoch 164/300
#
# Epoch 00164: LearningRateScheduler reducing learning rate to 0.0001853020366979763.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5001 - accuracy: 0.9360 - val_loss: 10.3936 - val_accuracy: 0.9365
# Epoch 165/300
#
# Epoch 00165: LearningRateScheduler reducing learning rate to 0.0001853020366979763.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4894 - accuracy: 0.9361 - val_loss: 10.7571 - val_accuracy: 0.9357
# Epoch 166/300
#
# Epoch 00166: LearningRateScheduler reducing learning rate to 0.0001853020366979763.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4939 - accuracy: 0.9363 - val_loss: 10.1711 - val_accuracy: 0.9380
# Epoch 167/300
#
# Epoch 00167: LearningRateScheduler reducing learning rate to 0.0001853020366979763.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4936 - accuracy: 0.9365 - val_loss: 10.6373 - val_accuracy: 0.9369
# Epoch 168/300
#
# Epoch 00168: LearningRateScheduler reducing learning rate to 0.0001853020366979763.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4859 - accuracy: 0.9363 - val_loss: 10.8510 - val_accuracy: 0.9364
# Epoch 169/300
#
# Epoch 00169: LearningRateScheduler reducing learning rate to 0.0001853020366979763.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4684 - accuracy: 0.9363 - val_loss: 11.0332 - val_accuracy: 0.9338
# Epoch 170/300
#
# Epoch 00170: LearningRateScheduler reducing learning rate to 0.0001853020366979763.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.4820 - accuracy: 0.9362 - val_loss: 10.7049 - val_accuracy: 0.9357
# Epoch 171/300
#
# Epoch 00171: LearningRateScheduler reducing learning rate to 0.00016677183302817866.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.4675 - accuracy: 0.9364 - val_loss: 11.3217 - val_accuracy: 0.9330
# Epoch 172/300
#
# Epoch 00172: LearningRateScheduler reducing learning rate to 0.00016677183157298714.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.4764 - accuracy: 0.9364 - val_loss: 11.4618 - val_accuracy: 0.9358
# Epoch 173/300
#
# Epoch 00173: LearningRateScheduler reducing learning rate to 0.00016677183157298714.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.4651 - accuracy: 0.9364 - val_loss: 10.7457 - val_accuracy: 0.9348
# Epoch 174/300
#
# Epoch 00174: LearningRateScheduler reducing learning rate to 0.00016677183157298714.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4809 - accuracy: 0.9363 - val_loss: 11.3698 - val_accuracy: 0.9340
# Epoch 175/300
#
# Epoch 00175: LearningRateScheduler reducing learning rate to 0.00016677183157298714.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.5046 - accuracy: 0.9361 - val_loss: 10.6524 - val_accuracy: 0.9378
# Epoch 176/300
#
# Epoch 00176: LearningRateScheduler reducing learning rate to 0.00016677183157298714.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5154 - accuracy: 0.9362 - val_loss: 10.5358 - val_accuracy: 0.9374
# Epoch 177/300
#
# Epoch 00177: LearningRateScheduler reducing learning rate to 0.00016677183157298714.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.5221 - accuracy: 0.9359 - val_loss: 10.8085 - val_accuracy: 0.9360
# Epoch 178/300
#
# Epoch 00178: LearningRateScheduler reducing learning rate to 0.00016677183157298714.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.4961 - accuracy: 0.9360 - val_loss: 10.1049 - val_accuracy: 0.9385
# Epoch 179/300
#
# Epoch 00179: LearningRateScheduler reducing learning rate to 0.00016677183157298714.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.4987 - accuracy: 0.9361 - val_loss: 10.5680 - val_accuracy: 0.9374
# Epoch 180/300
#
# Epoch 00180: LearningRateScheduler reducing learning rate to 0.00016677183157298714.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.5006 - accuracy: 0.9359 - val_loss: 11.1801 - val_accuracy: 0.9344
# Epoch 181/300
#
# Epoch 00181: LearningRateScheduler reducing learning rate to 0.00015009464841568844.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.4899 - accuracy: 0.9365 - val_loss: 10.4937 - val_accuracy: 0.9374
# Epoch 182/300
#
# Epoch 00182: LearningRateScheduler reducing learning rate to 0.000150094652781263.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5286 - accuracy: 0.9359 - val_loss: 11.6803 - val_accuracy: 0.9335
# Epoch 183/300
#
# Epoch 00183: LearningRateScheduler reducing learning rate to 0.000150094652781263.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.6166 - accuracy: 0.9356 - val_loss: 10.8470 - val_accuracy: 0.9380
# Epoch 184/300
#
# Epoch 00184: LearningRateScheduler reducing learning rate to 0.000150094652781263.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5836 - accuracy: 0.9356 - val_loss: 11.5982 - val_accuracy: 0.9360
# Epoch 185/300
#
# Epoch 00185: LearningRateScheduler reducing learning rate to 0.000150094652781263.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.5501 - accuracy: 0.9357 - val_loss: 11.8034 - val_accuracy: 0.9303
# Epoch 186/300
#
# Epoch 00186: LearningRateScheduler reducing learning rate to 0.000150094652781263.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.5204 - accuracy: 0.9359 - val_loss: 11.1315 - val_accuracy: 0.9373
# Epoch 187/300
#
# Epoch 00187: LearningRateScheduler reducing learning rate to 0.000150094652781263.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.5118 - accuracy: 0.9360 - val_loss: 11.2697 - val_accuracy: 0.9348
# Epoch 188/300
#
# Epoch 00188: LearningRateScheduler reducing learning rate to 0.000150094652781263.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.5098 - accuracy: 0.9360 - val_loss: 10.9762 - val_accuracy: 0.9362
# Epoch 189/300
#
# Epoch 00189: LearningRateScheduler reducing learning rate to 0.000150094652781263.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.4983 - accuracy: 0.9360 - val_loss: 10.5787 - val_accuracy: 0.9381
# Epoch 190/300
#
# Epoch 00190: LearningRateScheduler reducing learning rate to 0.000150094652781263.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.5103 - accuracy: 0.9361 - val_loss: 10.3159 - val_accuracy: 0.9380
# Epoch 191/300
#
# Epoch 00191: LearningRateScheduler reducing learning rate to 0.0001350851875031367.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.4724 - accuracy: 0.9364 - val_loss: 11.4346 - val_accuracy: 0.9360
# Epoch 192/300
#
# Epoch 00192: LearningRateScheduler reducing learning rate to 0.0001350851816823706.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.4786 - accuracy: 0.9360 - val_loss: 10.2264 - val_accuracy: 0.9384
# Epoch 193/300
#
# Epoch 00193: LearningRateScheduler reducing learning rate to 0.0001350851816823706.
# 4050/4050 [==============================] - 13s 3ms/step - loss: 10.4935 - accuracy: 0.9363 - val_loss: 10.8691 - val_accuracy: 0.9372
# Epoch 194/300
#
# Epoch 00194: LearningRateScheduler reducing learning rate to 0.0001350851816823706.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.4715 - accuracy: 0.9363 - val_loss: 10.7260 - val_accuracy: 0.9370
# Epoch 195/300
#
# Epoch 00195: LearningRateScheduler reducing learning rate to 0.0001350851816823706.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4837 - accuracy: 0.9363 - val_loss: 11.4298 - val_accuracy: 0.9347
# Epoch 196/300
#
# ...
# Epoch 234/300
#
# Epoch 00234: LearningRateScheduler reducing learning rate to 8.862938557285815e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4623 - accuracy: 0.9363 - val_loss: 10.3157 - val_accuracy: 0.9388
# Epoch 235/300
#
# Epoch 00235: LearningRateScheduler reducing learning rate to 8.862938557285815e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4537 - accuracy: 0.9363 - val_loss: 11.8521 - val_accuracy: 0.9328
# Epoch 236/300
#
# Epoch 00236: LearningRateScheduler reducing learning rate to 8.862938557285815e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4518 - accuracy: 0.9364 - val_loss: 10.5719 - val_accuracy: 0.9364
# Epoch 237/300
#
# Epoch 00237: LearningRateScheduler reducing learning rate to 8.862938557285815e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4503 - accuracy: 0.9361 - val_loss: 11.9569 - val_accuracy: 0.9337
# Epoch 238/300
#
# Epoch 00238: LearningRateScheduler reducing learning rate to 8.862938557285815e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4787 - accuracy: 0.9358 - val_loss: 10.5542 - val_accuracy: 0.9368
# Epoch 239/300
#
# Epoch 00239: LearningRateScheduler reducing learning rate to 8.862938557285815e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4513 - accuracy: 0.9365 - val_loss: 10.4400 - val_accuracy: 0.9372
# Epoch 240/300
#
# Epoch 00240: LearningRateScheduler reducing learning rate to 8.862938557285815e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4771 - accuracy: 0.9361 - val_loss: 10.8562 - val_accuracy: 0.9349
# Epoch 241/300
#
# Epoch 00241: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4645 - accuracy: 0.9361 - val_loss: 10.3543 - val_accuracy: 0.9372
# Epoch 242/300
#
# Epoch 00242: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4529 - accuracy: 0.9366 - val_loss: 10.4090 - val_accuracy: 0.9382
# Epoch 243/300
#
# Epoch 00243: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4616 - accuracy: 0.9365 - val_loss: 10.7135 - val_accuracy: 0.9365
# Epoch 244/300
#
# Epoch 00244: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4630 - accuracy: 0.9361 - val_loss: 10.3989 - val_accuracy: 0.9361
# Epoch 245/300
#
# Epoch 00245: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4618 - accuracy: 0.9364 - val_loss: 11.0066 - val_accuracy: 0.9352
# Epoch 246/300
#
# Epoch 00246: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4605 - accuracy: 0.9365 - val_loss: 11.2060 - val_accuracy: 0.9353
# Epoch 247/300
#
# Epoch 00247: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4478 - accuracy: 0.9363 - val_loss: 10.1741 - val_accuracy: 0.9375
# Epoch 248/300
#
# Epoch 00248: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4895 - accuracy: 0.9363 - val_loss: 10.6650 - val_accuracy: 0.9376
# Epoch 249/300
#
# Epoch 00249: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4622 - accuracy: 0.9363 - val_loss: 10.9107 - val_accuracy: 0.9376
# Epoch 250/300
#
# Epoch 00250: LearningRateScheduler reducing learning rate to 7.976644701557234e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4614 - accuracy: 0.9362 - val_loss: 10.8884 - val_accuracy: 0.9345
# Epoch 251/300
#
# Epoch 00251: LearningRateScheduler reducing learning rate to 7.178980231401511e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4695 - accuracy: 0.9365 - val_loss: 10.5516 - val_accuracy: 0.9376
# Epoch 252/300
#
# Epoch 00252: LearningRateScheduler reducing learning rate to 7.178980013122782e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4648 - accuracy: 0.9360 - val_loss: 10.4807 - val_accuracy: 0.9372
# Epoch 253/300
#
# Epoch 00253: LearningRateScheduler reducing learning rate to 7.178980013122782e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4385 - accuracy: 0.9363 - val_loss: 10.8611 - val_accuracy: 0.9361
# Epoch 254/300
#
# Epoch 00254: LearningRateScheduler reducing learning rate to 7.178980013122782e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4803 - accuracy: 0.9362 - val_loss: 10.8823 - val_accuracy: 0.9359
# Epoch 255/300
#
# Epoch 00255: LearningRateScheduler reducing learning rate to 7.178980013122782e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4469 - accuracy: 0.9364 - val_loss: 11.5480 - val_accuracy: 0.9351
# Epoch 256/300
#
# Epoch 00256: LearningRateScheduler reducing learning rate to 7.178980013122782e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4424 - accuracy: 0.9364 - val_loss: 11.1769 - val_accuracy: 0.9377
# Epoch 257/300
#
# Epoch 00257: LearningRateScheduler reducing learning rate to 7.178980013122782e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4642 - accuracy: 0.9361 - val_loss: 11.0423 - val_accuracy: 0.9353
# Epoch 258/300
#
# Epoch 00258: LearningRateScheduler reducing learning rate to 7.178980013122782e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4606 - accuracy: 0.9359 - val_loss: 10.9968 - val_accuracy: 0.9365
# Epoch 259/300
#
# Epoch 00259: LearningRateScheduler reducing learning rate to 7.178980013122782e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4648 - accuracy: 0.9363 - val_loss: 10.2364 - val_accuracy: 0.9377
# Epoch 260/300
#
# Epoch 00260: LearningRateScheduler reducing learning rate to 7.178980013122782e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4825 - accuracy: 0.9361 - val_loss: 10.2865 - val_accuracy: 0.9378
# Epoch 261/300
#
# Epoch 00261: LearningRateScheduler reducing learning rate to 6.461082011810504e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4816 - accuracy: 0.9359 - val_loss: 10.5536 - val_accuracy: 0.9343
# Epoch 262/300
#
# Epoch 00262: LearningRateScheduler reducing learning rate to 6.461082375608385e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4719 - accuracy: 0.9364 - val_loss: 10.5488 - val_accuracy: 0.9373
# Epoch 263/300
#
# Epoch 00263: LearningRateScheduler reducing learning rate to 6.461082375608385e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4544 - accuracy: 0.9361 - val_loss: 10.6244 - val_accuracy: 0.9374
# Epoch 264/300
#
# Epoch 00264: LearningRateScheduler reducing learning rate to 6.461082375608385e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4707 - accuracy: 0.9362 - val_loss: 10.3753 - val_accuracy: 0.9377
# Epoch 265/300
#
# Epoch 00265: LearningRateScheduler reducing learning rate to 6.461082375608385e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4542 - accuracy: 0.9366 - val_loss: 10.7045 - val_accuracy: 0.9370
# Epoch 266/300
#
# Epoch 00266: LearningRateScheduler reducing learning rate to 6.461082375608385e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4379 - accuracy: 0.9367 - val_loss: 11.2721 - val_accuracy: 0.9348
# Epoch 267/300
#
# Epoch 00267: LearningRateScheduler reducing learning rate to 6.461082375608385e-05.
# 4050/4050 [==============================] - 12s 3ms/step - loss: 10.4540 - accuracy: 0.9364 - val_loss: 10.0797 - val_accuracy: 0.9385
# Epoch 268/300
#
# Epoch 00268: LearningRateScheduler reducing learning rate to 6.461082375608385e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4511 - accuracy: 0.9366 - val_loss: 11.7381 - val_accuracy: 0.9328
# Epoch 269/300
#
# Epoch 00269: LearningRateScheduler reducing learning rate to 6.461082375608385e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4448 - accuracy: 0.9364 - val_loss: 10.6671 - val_accuracy: 0.9368
# Epoch 270/300
#
# Epoch 00270: LearningRateScheduler reducing learning rate to 6.461082375608385e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4700 - accuracy: 0.9362 - val_loss: 10.5268 - val_accuracy: 0.9363
# Epoch 271/300
#
# Epoch 00271: LearningRateScheduler reducing learning rate to 5.8149741380475466e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4602 - accuracy: 0.9364 - val_loss: 10.3876 - val_accuracy: 0.9372
# Epoch 272/300
#
# Epoch 00272: LearningRateScheduler reducing learning rate to 5.81497406528797e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4432 - accuracy: 0.9366 - val_loss: 11.1004 - val_accuracy: 0.9351
# Epoch 273/300
#
# Epoch 00273: LearningRateScheduler reducing learning rate to 5.81497406528797e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4877 - accuracy: 0.9364 - val_loss: 10.8802 - val_accuracy: 0.9357
# Epoch 274/300
#
# Epoch 00274: LearningRateScheduler reducing learning rate to 5.81497406528797e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4720 - accuracy: 0.9363 - val_loss: 10.8669 - val_accuracy: 0.9362
# Epoch 275/300
#
# Epoch 00275: LearningRateScheduler reducing learning rate to 5.81497406528797e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4653 - accuracy: 0.9361 - val_loss: 10.5883 - val_accuracy: 0.9350
# Epoch 276/300
#
# Epoch 00276: LearningRateScheduler reducing learning rate to 5.81497406528797e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4633 - accuracy: 0.9365 - val_loss: 10.1736 - val_accuracy: 0.9386
# Epoch 277/300
#
# Epoch 00277: LearningRateScheduler reducing learning rate to 5.81497406528797e-05.
# 4050/4050 [==============================] - 11s 3ms/step - loss: 10.4667 - accuracy: 0.9366 - val_loss: 10.8766 - val_accuracy: 0.9387
# Epoch 278/300
#
# Epoch 00278: LearningRateScheduler reducing learning rate to 5.81497406528797e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4450 - accuracy: 0.9369 - val_loss: 11.3897 - val_accuracy: 0.9362
# Epoch 279/300
#
# Epoch 00279: LearningRateScheduler reducing learning rate to 5.81497406528797e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4696 - accuracy: 0.9360 - val_loss: 11.8162 - val_accuracy: 0.9349
# Epoch 280/300
#
# Epoch 00280: LearningRateScheduler reducing learning rate to 5.81497406528797e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4667 - accuracy: 0.9364 - val_loss: 10.9415 - val_accuracy: 0.9359
# Epoch 281/300
#
# Epoch 00281: LearningRateScheduler reducing learning rate to 5.233476658759173e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4433 - accuracy: 0.9362 - val_loss: 10.6142 - val_accuracy: 0.9362
# Epoch 282/300
#
# Epoch 00282: LearningRateScheduler reducing learning rate to 5.233476622379385e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4637 - accuracy: 0.9366 - val_loss: 10.9496 - val_accuracy: 0.9367
# Epoch 283/300
#
# Epoch 00283: LearningRateScheduler reducing learning rate to 5.233476622379385e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4381 - accuracy: 0.9362 - val_loss: 11.0121 - val_accuracy: 0.9358
# Epoch 284/300
#
# Epoch 00284: LearningRateScheduler reducing learning rate to 5.233476622379385e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4544 - accuracy: 0.9363 - val_loss: 10.2890 - val_accuracy: 0.9379
# Epoch 285/300
#
# Epoch 00285: LearningRateScheduler reducing learning rate to 5.233476622379385e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4557 - accuracy: 0.9364 - val_loss: 10.5524 - val_accuracy: 0.9369
# Epoch 286/300
#
# Epoch 00286: LearningRateScheduler reducing learning rate to 5.233476622379385e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4562 - accuracy: 0.9363 - val_loss: 10.4211 - val_accuracy: 0.9378
# Epoch 287/300
#
# Epoch 00287: LearningRateScheduler reducing learning rate to 5.233476622379385e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4651 - accuracy: 0.9363 - val_loss: 10.4949 - val_accuracy: 0.9376
# Epoch 288/300
#
# Epoch 00288: LearningRateScheduler reducing learning rate to 5.233476622379385e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4654 - accuracy: 0.9364 - val_loss: 10.9053 - val_accuracy: 0.9346
# Epoch 289/300
#
# Epoch 00289: LearningRateScheduler reducing learning rate to 5.233476622379385e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4503 - accuracy: 0.9367 - val_loss: 10.7792 - val_accuracy: 0.9378
# Epoch 290/300
#
# Epoch 00290: LearningRateScheduler reducing learning rate to 5.233476622379385e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4445 - accuracy: 0.9367 - val_loss: 11.8308 - val_accuracy: 0.9341
# Epoch 291/300
#
# Epoch 00291: LearningRateScheduler reducing learning rate to 4.7101289601414466e-05.
# 4050/4050 [==============================] - 10s 3ms/step - loss: 10.4664 - accuracy: 0.9363 - val_loss: 10.2660 - val_accuracy: 0.9376
# Epoch 292/300
#
# Epoch 00292: LearningRateScheduler reducing learning rate to 4.7101289965212345e-05.
# 4050/4050 [==============================] - 9s 2ms/step - loss: 10.4611 - accuracy: 0.9365 - val_loss: 10.7157 - val_accuracy: 0.9375
# Epoch 293/300
#
# Epoch 00293: LearningRateScheduler reducing learning rate to 4.7101289965212345e-05.
# 4050/4050 [==============================] - 9s 2ms/step - loss: 10.4636 - accuracy: 0.9359 - val_loss: 10.5509 - val_accuracy: 0.9366
# Epoch 294/300
#
# Epoch 00294: LearningRateScheduler reducing learning rate to 4.7101289965212345e-05.
# 4050/4050 [==============================] - 9s 2ms/step - loss: 10.4491 - accuracy: 0.9366 - val_loss: 10.2665 - val_accuracy: 0.9383
# Epoch 295/300
#
# Epoch 00295: LearningRateScheduler reducing learning rate to 4.7101289965212345e-05.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.4610 - accuracy: 0.9361 - val_loss: 10.4020 - val_accuracy: 0.9378
# Epoch 296/300
#
# Epoch 00296: LearningRateScheduler reducing learning rate to 4.7101289965212345e-05.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.4737 - accuracy: 0.9363 - val_loss: 10.6500 - val_accuracy: 0.9366
# Epoch 297/300
#
# Epoch 00297: LearningRateScheduler reducing learning rate to 4.7101289965212345e-05.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.4525 - accuracy: 0.9366 - val_loss: 10.4027 - val_accuracy: 0.9363
# Epoch 298/300
#
# Epoch 00298: LearningRateScheduler reducing learning rate to 4.7101289965212345e-05.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.4613 - accuracy: 0.9366 - val_loss: 10.5751 - val_accuracy: 0.9378
# Epoch 299/300
#
# Epoch 00299: LearningRateScheduler reducing learning rate to 4.7101289965212345e-05.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.4570 - accuracy: 0.9364 - val_loss: 10.4283 - val_accuracy: 0.9372
# Epoch 300/300
#
# Epoch 00300: LearningRateScheduler reducing learning rate to 4.7101289965212345e-05.
# 4050/4050 [==============================] - 7s 2ms/step - loss: 10.4507 - accuracy: 0.9363 - val_loss: 11.1172 - val_accuracy: 0.9364
# [INFO    ] Done training. Time elapsed: 1:06:40.289712 sec
# [INFO    ] Epoch 300/300 - loss: 10.446746826171875 - val_loss: 11.117185592651367

# %%
x = np.concatenate((x_train_displ, x_test_displ),axis = 0)
y = np.concatenate((y_train_displ, y_test_displ),axis = 0)
dxy = np.concatenate((dxy_train_displ, dxy_test_displ),axis = 0)
k_fold_validation(model = qmodel, 
                  x = x,  
                  y = y, 
                  dxy = dxy, 
                  folds =50)
# Out:
# Average RMSE for 50-fold cv for y: 52.02684811031029
# Average RMSE for 50-fold cv for dxy: 17.39007758422833

# %%
# import pickle
# with open(os.getcwd()+'/trainHistoryDictL2', 'wb') as file_pi:
#     pickle.dump(history.history, file_pi)

# %%
plt.figure(figsize=(5,5),dpi = 70)
plt.plot(history.history['loss'], color = "blue")
plt.plot(history.history['val_loss'], color = "red")
plt.title('Change in huber loss for the quantized model')
plt.xlabel('epoch')
plt.ylabel('loss')
plt.legend(['train', 'validation'], loc='upper right')
plt.show()

# %%
plt.figure(figsize=(5,5),dpi = 70)
plt.plot(history.history['accuracy'], color = "blue")
plt.plot(history.history['val_accuracy'], color = "red")
# plt.title('Change in accuracy for the quantized model')
plt.xlabel('epoch')
plt.ylabel('accuracy')
plt.legend(['train', 'validation'], loc='lower right')
plt.show()

# %%
training_params = {"retrain epochs":normal_epochs, 
                   "batch size"    :normal_batch_size, 
                   "learning rate" :learning_rate,
                   "BN momentum"   :0.9,
                   "BN epsilon"    :1e-4,
                   "L1 Reg"        :l1_reg,
                   "L2 Reg"        :l2_reg
                  }
df = pd.DataFrame(training_params.items(), 
                  columns=['Training Parameters', 'Value'],
                  index = [i+1 for i in range(len(training_params))])
df
# Out:
#   Training Parameters     Value
# 1      retrain epochs  300.0000
# 2          batch size  500.0000
# 3       learning rate    0.0010
# 4         BN momentum    0.9000
# 5          BN epsilon    0.0001
# 6              L1 Reg    0.0000
# 7              L2 Reg    0.0001

# %%
def __generate_delta_plots__(model,
                             x,
                             y,
                             dxy,batch_size = 4096,
                             min_y_val = 20):
    
    # Predictions
    y_test_true = y.copy()
    y_test_true /= reg_pt_scale

    y_test_sel = (np.abs(1.0/y) >= min_y_val/reg_pt_scale)

    y_test_meas_ = model.predict(x, batch_size=4096)
    y_test_meas = y_test_meas_[:,0]
    y_test_meas /= reg_pt_scale
    y_test_meas = y_test_meas.reshape(-1)

    dxy_test_true = dxy.copy()
    dxy_test_true /= reg_dxy_scale

    #dxy_test_sel = (np.abs(dxy_test_true) >= 25)

    dxy_test_meas = y_test_meas_[:,1]
    dxy_test_meas /= reg_dxy_scale
    dxy_test_meas = dxy_test_meas.reshape(-1)
    
    # Plot Delta(q/pT)/pT
    plt.figure(figsize=(5,5),dpi = 75)
    yy = ((np.abs(1.0/y_test_meas) - np.abs(1.0/y_test_true))/np.abs(1.0/y_test_true))
    hist, edges, _ = plt.hist(yy, bins=100, range=(-2.0,2.0-eps), histtype='stepfilled', facecolor='red', alpha=0.3)
    plt.xlabel(r'$\Delta(p_{T})_{\mathrm{meas-true}}/{(p_{T})}_{true}$ [1/GeV]')
    plt.ylabel(r'entries')
    logger.info('# of entries: {0}, mean: {1}, std: {2}'.format(len(yy), np.mean(yy), np.std(yy[np.abs(yy)<0.4])))

    popt = fit_gaus(hist, edges, mu=np.mean(yy), sig=np.std(yy[np.abs(yy)<2.0]))
    logger.info('gaus fit (a, mu, sig): {0}'.format(popt))
    xdata = (edges[1:] + edges[:-1])/2
    plt.plot(xdata, gaus(xdata, popt[0], popt[1], popt[2]), color='red')
    plt.show()

    # Plot Delta(dxy)
    plt.figure(figsize=(5,5),dpi = 75)
    yy = (dxy_test_meas - dxy_test_true)[y_test_sel]
    hist, edges, _ = plt.hist(yy, bins=100, range=(-50,50), histtype='stepfilled', facecolor='red', alpha=0.3)
    plt.xlabel(r'$\Delta(d_{0})_{\mathrm{meas-true}}$ [cm]')
    plt.ylabel(r'entries')
    logger.info('# of entries: {0}, mean: {1}, std: {2}'.format(len(yy), np.mean(yy), np.std(yy)))

    popt = fit_gaus(hist, edges, mu=np.mean(yy), sig=np.std(yy))
    logger.info('gaus fit (a, mu, sig): {0}'.format(popt))
    xdata = (edges[1:] + edges[:-1])/2
    plt.plot(xdata, gaus(xdata, popt[0], popt[1], popt[2]), color='red')
    plt.show()

# %%
# __generate_delta_plots__(model = qmodel,
#                         x = x_test_displ,
#                         y = y_test_displ,
#                         dxy = dxy_test_displ
#                         )

# %% [markdown]
# ### Saving the optimal quantized model:

# %%
# model_for_export = qmodel
# qkeras_file = "models/quantized_DNN_affine_BN_bits_10_int_5.h5"
# weights_file = "models/quantized_DNN_affine_BN_bits_10_int_5"
# # save quantized weights
# utils.model_save_quantized_weights(model_for_export, weights_file)
# # save keras.save() h5 version of quantized model
# tf.keras.models.save_model(model_for_export, qkeras_file, include_optimizer=False)
# print('Saved quantized Keras model to:', qkeras_file)
# Out:
# ... quantizing model
#   bn-1 has not been quantized
#   bn-2 has not been quantized
#   bn-3 has not been quantized
# Saved quantized Keras model to: models/quantized_DNN_affine_BN_bits_10_int_5.h5

# %% [markdown]
# ### Loading the quantized model for assessment:

# %%
# qkeras_file = "model/quantized_DNN_affine_BN.h5"
# weights_file = "model/quantized_DNN_weights_affine_BN"
# loaded_qmodel = utils.load_qmodel(filepath=qkeras_file)

# %%
# loaded_qmodel.load_weights(weights_file)

# %%
# loaded_qmodel.summary()

# %%
# utils.get_model_sparsity(model=loaded_qmodel,per_layer=True)

# %%
## END ############################################################################################
